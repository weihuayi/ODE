# %% [markdown]
# 解对常数的独立性是指，对$y=\varphi(x,c_1,c_2,\cdots ,c_{n})$及其n-1阶偏导数关于n个常数$c_1,c_2,\cdots,c_{n}$的$Jocabi$行列式不为零。

# %% [markdown]
# 一次有理整式：对变数字母与数仅限于有限次加、减、乘、乘方运算的代数式，即除式不含变数字母的，切且次数最大值为一的有理式称为一次有理整式。

# %% [markdown]
# # 习题1.2

# %% [markdown]
# # 3·验证下列各函数是相应微分方程的解

# %% [markdown]
# ## （7）$y=x^{2}+1,y\prime=y^{2}-(x^{2}+1)y+2x$;

# %% [markdown]
# 解：$\frac{dy}{dx}=2x;y^{2}=x^{4}+2x^2+1,(x^2+1)y=x^{4}+2x^2+1,$所以，左式=2x=右式，此函数是该方程的解

# %% [markdown]
# <font color="red">正确

# %% [markdown]
# ## （8）$y=\frac{g(x)}{f(x)},y\prime=\frac{f\prime(x)}{g(x)}y^2-\frac{g\prime(x)}{f(x)}$;

# %% [markdown]
# 解：左式$=y\prime=\frac{g\prime(x)f(x)-f\prime(x)g(x)}{f^2(x)}$

# %% [markdown]
# 右式$=\frac{f\prime(x)g(x)}{f^2(x)}-\frac{g\prime(x)f(x)}{f^2(x)}=$左式；
# 所以此函数是该方程的解

# %% [markdown]
# <font color="red">题抄错了

# %% [markdown]
# # 4·给定一阶微分方程$\frac{dy}{dx}=2x$;

# %% [markdown]
# ### (1)求出它的通解；

# %% [markdown]
# 解：由题知$dy=2xdx$,两边积分得$y=x^2+c$,

# %% [markdown]
# <font color="red">正确

# %% [markdown]
# ### (2)求通过点（1，4）的特解；

# %% [markdown]
# 解：将$y=4,x=1$代入方程通解中,得$4=1+c$

# %% [markdown]
# 所以$c=3$,代入通解得$y=x^2+3$

# %% [markdown]
# <font color="red">正确

# %% [markdown]
# ### （3）求出与直线$y=2x+3$相切的解；

# %% [markdown]
# 解：对通解求导，使其等于直线斜率$\implies 2x=2\implies x=1$

# %% [markdown]
# 所以切点横坐标为1，代入通解及切线得$2+3=1+c\implies c=4$

# %% [markdown]
# 所以特解为$y=x^2+4$

# %% [markdown]
# <font color="red">正确

# %% [markdown]
# ## (4)求出满足条件$\int_0^1y\mathrm dx=2$的解；

# %% [markdown]
# 解：$\int_0^1y\mathrm dx=\left.\frac{x^3}{3}\right.\mid_0^1+c=2\implies\frac{1}{3}+c=2\implies c=\frac{5}{3}$

# %% [markdown]
# 所以特解为$y=x^2+\frac{5}{3}$

# %% [markdown]
# ## （5）绘出（2），（3），（4）中的解的图形;

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,7))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x),-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x),-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# <font color="red">正确
