# %% [markdown]
# 1:有理整式亦称整式.一种基本的有理式.对变数字母与数仅限于有限次加、减、乘、乘方运算的代数式，即除式不含变数字母的有理式称为有理整式.整式包括单项式和多项式.可以认为有理整式即是多项式。

# %% [markdown]
# 2：对常数的独立性是指，对$\varphi$及其$n-1$阶偏导数关于$n$个常数$c1,c2,\cdots,c_n$的雅可比行列式不为0。

# %% [markdown]
# 3：证明：设 $\mathbf y_1(t)$ 是
#
#  $$\frac{d\mathbf y}{dt}=\mathbf f(\mathbf y), \mathbf y(0) = \mathbf y_0$$
#
# 解, 则 $\mathbf y_2(t)= \mathbf y_1(t - t_0)$ 是
# $$\frac{d\mathbf y}{dt}=\mathbf f(\mathbf y), \mathbf y(t_0) = \mathbf y_0$$
# 的解.
# $$\mathbf f(y_2(t))=\mathbf f(y_1(t-t_0))=\frac {\mathrm d y_1(t-t_0)} {\mathrm d t}=\frac {d y_2} {d t}$$
# $$y_2(t_0)=y_1(0)=y_0$$

# %% [markdown]
# 4:(1)
# $y=x^2+1,y^\prime=y^2-(x^2+1)*y+2*x$

# %%
var('x y')
y=x^2+1
de=diff(y,x)==y^2-(x^2+1)*y+2*y
show(de)
# Out:
# 2*x == 2*x^2 + 2

# %% [markdown]
# (2):$y=-\frac {g(x)} {f(x)}$,$y^\prime=\frac {f^\prime(x)} {g(x)}*y^2-\frac {g^\prime(x)} {f(x)}$

# %%
var('x y')
g=function('g')(x)
show(g)
f=function('f')(x)
show(f)
y=-g/f
de=diff(y,x)==(diff(f,x)/g)*y^2-diff(g,x)/f
show(de)
# Out:
# g(x)
# f(x)
# g(x)*D[0](f)(x)/f(x)^2 - D[0](g)(x)/f(x) == g(x)*D[0](f)(x)/f(x)^2 - D[0](g)(x)/f(x)

# %% [markdown]
# 5:给定一阶微分方程$\frac {\mathrm d y}{\mathrm d x}=2*x$

# %% [markdown]
# 1)求出通解
#     （2）求通过点（1，4）的特解
#     （3）求出与直线$y=2*x+3$相切的的解
#     （4）求出满足条件$\int(1,0)ydx=2$

# %% [markdown]
# 1:$$dy=2*x*dx$$
# 两边积分$$\int dy=\int 2*x*dx$$
# 得解$$y=x^2+c$$

# %% [markdown]
# 2:$y=x^2+c$代入（1，4），得c=3$$y=x^2+3$$

# %%
var('x')
y(x)=x^2+3
plot(y,(x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 3:因为和$y=2*x+3$相切，$x^2+c=2*x+3$,
# $$=>x^2-2*x+(c-3)=0$$
# $$2^2-4*(c-3)=0$$
# $$=>c-3=1$$
# $$c=4$$
# $$=>y=x^2+4$$

# %%
var('x')
y(x)=x^2+4
plot(y,(x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 4:因为$$\int_0^1 ydx=\frac {x^3}{3}+c*x$$
# $$=> \frac {1}{3}+c=2$$
# $$=> c=\frac{4}{3}$$
# $$y=x^2+\frac{4}{3}$$

# %%
var('x')
y(x)=x^2+(4/3)
plot(y,(x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 第二次

# %% [markdown]
# 1：$x\frac{dy}{dx}-y+\sqrt(x^2-y^2)=0$

# %% [markdown]
# **解**设$\frac{y}{x}=u$
# 1. 分离变量$$\frac{du}{\sqrt(1-u^2)}=-\frac{dx}{x}$$
# 2. 两边积分$$\int\frac{du}{\sqrt(1-u^2)}=-\int\frac{dx}{x}$$
# $$=>arcsin\frac{y}{x}+ln|x|=c$$

# %% [markdown]
# <font color="red">**答案不完整**

# %% [markdown]
# 2:$tanydx-cotxdy=0$$

# %% [markdown]
# **解**当$tany=0$时，$y=k\pi$是方程的解
# 1. 分离变量 $$cot ydy=tan xdx$$
# 1. 两边积分 $$\int cot ydy=\int tan xdx$$
# $$=> siny=\frac {c}{cosx}$$

# %% [markdown]
# <font color="red">**正确**

# %% [markdown]
# 3:$\frac {dy}{dx}=\frac {y^6-2*x^2}{2*x*y^5+x^2*y^2}$

# %% [markdown]
# 可令$u=y^2$,
#  方程化为$$\frac {du}{dx}=\frac{3u^2-6*x^2}{2*x*u+x^2}$$
#  再令$v=\frac{u}{x}$
#   化为$$x*\frac{dv}{dx}+v=\frac{3*v^2-6}{2*v+1}$$
#   分离变量$$\frac{7*dv}{5*(v-3)}+\frac{3*dv}{5*(v+2)}=\frac{dx}{x}$$
#   两边积分$$(v-3)^7*(v+2)^3=c*x^5$$
#   代换并化简$$(y^3-3*x)^7*(y^3+2*x)=c*x^{15}$$

# %% [markdown]
# 4:$\frac {dy}{dx}=\frac{2*x^3+3*x*y^2+x}{3*x^2*y+2*y^2-y}$

# %% [markdown]
# 方程化为$\frac {dy}{dx}=\frac{x*(2*x^2+3*y^2+1)}{y*(3*x^2+2*y-1)}$
#
# $=>\frac {dy^2}{dx^2}=\frac{2*x^2+3*y^2+1}{3*x^2+2*y-1}$
#
# 令$u=y^2,v=x^2$
#
# 则有$$\frac{du}{dv}=\frac{2u+3v+1}{3*v+2*u-1}$$
# 令
# $$
# \begin{cases}
# X=v-1\\Y=u+1
# \end{cases}
# $$
# 化为$$\frac {dY}{dX}=\frac {2+3\frac{Y}{X}}{3+2\frac{Y}{X}}$$
# 令$t=\frac{Y}{X},$有$\frac{dY}{dX}=t+X*\frac{dt}{dY}$
#
# 所以$X*\frac{dt}{dY}=\frac{2-2*t^2}{3+2*t}$
#
#
# 分离变量并积分$$y^2+x^2=c*(y^2-x^2+2)^5$$

# %% [markdown]
# <font color="red">**正确**

# %% [markdown]
# <font color="red">**$A^-$**
