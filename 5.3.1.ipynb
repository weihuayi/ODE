# %% [markdown]
# ## § 5.3 常系数线性微分方程组/Coefficients Linear ODEs/

# %% [markdown]
# ### 本节主要内容 /Main Contents/
#
# 1、 常系数齐线性微分方程组
#
# $$
# x'=Ax
# $$
#
# 的基解矩阵的结构 , 这里 $A$ 是 $n\times n$ 常数矩阵.
#
# ２、通过代数的方法 , 寻求
#
# $$
# x'=Ax
# $$
#
# 的一个基解矩阵.
#
# ３、拉普拉斯变换在常系数线性微分方程组中的应用.

# %% [markdown]
# ### 5.3.1 矩阵指数 exp A 的定义和性质

# %% [markdown]
# 无穷矩阵级数
#
# $$
# \begin{aligned}
# \displaystyle\sum_{k=1}^{\infty} A_k
# &=A_1+A_2+A_3+\dots+A_K+\dots\\
# &=\left( a_{ij}^{(1)}\right)_{n\times n}+\left( a_{ij}^{(2)}\right)_{n\times n}+\dots+\left( a_{ij}^{(k)}\right)_{n\times n}+\dots\\
# &=\left(a_{ij}^{(1)}+a_{ij}^{(2)}+\dots+a_{ij}^{(k)}+\dots\right)_{n\times n}\\
# \end{aligned}
# $$
#
# 如果每个 $\displaystyle\sum_{k=1}^{\infty} a_{ij}^{(k)}$, $i,j=1,2,\dots,n$ 收敛,则 $\displaystyle\sum_{k=1}^{\infty} A_k$收敛.
#
# 判断无穷矩阵级数 $\displaystyle\sum_{k=1}^{\infty} A_k$ 收敛的法则:
#
# $\forall k$, $ \mid\mid A_k\mid\mid=\displaystyle\sum_{j=1}^{\infty}\displaystyle\sum_{i=1}^{\infty}\mid a_{ij}^{(k)}\mid\leq M_k$,而级数 $\displaystyle\sum_{k=1}^{\infty} M_k$ 收敛,则$\displaystyle\sum_{k=1}^{\infty} A_k$收敛.
#
# 同理 , 可给出 $\displaystyle\sum_{k=1}^{\infty} A_k{(t)}$ 在区间 $I$ 上的一致收敛的定义 , 和函数等类似的结果.

# %% [markdown]
# **定义 $1$ ** 矩阵指数
#
# $$
# \exp A=\displaystyle\sum_{k=0}^{\infty} \frac{A^k}{k!}=E+A+\frac{A^2}{2!}+\dots+\frac{A^m}{m!}+\dots
# $$
#
# $E$ 为 $n$ 阶单位矩阵,$A^m$ 是矩阵 $A$ 的 $m$ 次幂.
#
# $A^0=E$ , $n!=1$, $\exp A$ 是一个确定的矩阵.
#
# 对于一切正整数 $k$ ,$\mid\mid\frac{A^k}{k!}\mid\mid\leq\frac{\mid\mid A^k\mid\mid}{k!}\leq\frac{{\mid\mid A\mid\mid}^k}{k!}$ 而
#
# $$
# \displaystyle\sum_{k=0}^{\infty}\frac{\mid\mid A\mid\mid^k}{k!}=\mid\mid E\mid\mid+\displaystyle\sum_{k=0}^{\infty}\mid\mid A\mid\mid^k=e^{\mid\mid A\mid\mid}+n-1
# $$
#
# 收敛,则 $\displaystyle\sum_{k=0}^{\infty} \frac{A^k}{k!}$ 收敛.

# %% [markdown]
# **定义 $2$** 矩阵指数函数 $\exp A t =\displaystyle\sum_{k=0}^{\infty} \frac{A^k t^k}{k!}$ 在 $t$ 的任何有限区间上是一致收敛的.
#
# 对于一切正整数 $k$, 当 $\mid t\mid\leq c$ ($c$是某一正常数时),有
#
# $$
# \mid\mid\frac{A^k t^k}{k!}\mid\mid\leq\frac{\mid\mid A \mid\mid^k \mid t\mid^k}{k!}\leq\frac{\mid\mid A\mid\mid^k c^k}{k!}
# $$
#
# 而数值级数
#
# $$
# \displaystyle\sum_{k=0}^{\infty}\frac{\left(\mid\mid A\mid\mid c\right)^k}{k!}
# $$
#
# 是收敛的,因而
#
# $$
# \exp A t =\displaystyle\sum_{k=0}^{\infty} \frac{A^k t^k}{k!}
# $$
#
# 在 $t$ 的任何有限区间上是一致收敛的.

# %% [markdown]
# ### $\exp A$ 性质

# %% [markdown]
# **性质 $1$ ** 如果矩阵 $A$ ,$B$ 是可交换的,即 $AB=BA$ ,则
#
# $$
# \exp(A+B)=\exp A \cdot \exp B
# $$
#
# **证** 由于级数 $\exp A =\displaystyle\sum_{k=0}^{\infty} \frac{A^k}{k!}$, $\exp B =\displaystyle\sum_{k=0}^{\infty} \frac{B^k}{k!}$
#
# 绝对收敛,由绝对收敛级数的乘法定理,得
#
# $$
# \exp A \cdot \exp B=(E+A+\frac{A^2}{2!}+\dots+)(E+B+\frac{B^2}{2!}+\dots)=E+(A+B)+\frac{1}{2!}(A^2+2AB+B^2)+\dots
# $$
#
# 另一方面,由二项式定理及 $AB=BA$
#
# 由绝对收敛级数的乘法定理,得
#
# $$
# \exp A \cdot \exp B=(E+A+\frac{A^2}{2!}+\dots+)(E+B+\frac{B^2}{2!}+\dots)=E+(A+B)+\frac{1}{2!}(A^2+2AB+B^2)+\dots
# $$
#
# 另一方面,由二项式定理及 $AB=BA$ ,
#
# $$
# \begin{aligned}
# \exp (A+B)
# &=E+(A+B)+\frac{1}{2!}(A+B)^2+\dots\\
# &=E+(A+B)+\frac{1}{2!}(A^2+2AＢ＋Ｂ^２)＋\dots\\
# \end{aligned}
# $$
#
# $$
# \exp (A+B)=\exp A \cdot \exp B
# $$

# %% [markdown]
# **性质$2$** 对于任何矩阵 $A$ , $(\exp A)^{-1}$  存在 , 且
#
# $$
# (\exp A)^{-1}=\exp(-A)
# $$

# %% [markdown]
# **证** $A$ 与 $-A$ 是可交换的,故在
#
# $$
# \exp (A+B)=\exp A \cdot \exp B
# $$
#
# 中,令 $B = - A$ 得
#
# $$
# \exp A \exp( − A ) = \exp( A + ( − A )) = \exp 0 = E
# $$
#
# $$
# (\exp A ) = \exp( − A )
# $$

# %% [markdown]
# **性质$3$** 如果 $T$ 是非奇异矩阵,则
#
# $$
# \exp( T^{-1} AT ) = T^{-1} (\exp A ) T
# $$
#
# 事实上
# $$
# \begin{aligned}
# \exp( T^{-1} AT)
# &=E+\displaystyle\sum_{k=1}^{\infty}\frac{(T^{-1} AT)^k}{k!}\\
# &=E+\displaystyle\sum_{k=1}^{\infty}\frac{T^{-1} A^kT}{k!}\\
# &=E+T^{-1}(\displaystyle\sum_{k=1}^{\infty} \frac{A^k}{k!})T\\
# &=T^{-1}(\exp A)T\\
# \end{aligned}
# $$
#
# $$
# (T^{-1}AT)^2 = T^{−1}AT T^{−1} AT = T^{−1}A^2T
# $$

# %% [markdown]
# **定理$9$** 矩阵 $\Phi(t)= \exp A t$ 是
# $$
# x'=Ax
# $$
#
# 的标准基解矩阵.$\Phi(0)= E$

# %% [markdown]
# **证明**
# $$
# \begin{aligned}
# \Phi(t)'
# &=(\exp A t)'\\
# &=A+\frac{A^2 t}{1!}+\frac{A^3 t^2}{2!}+\dots+\frac{A^K t^{k-1}}{(k-1)!}+\frac{A^{K+1} t^k}{k!}+\dots\\
# &=A\exp A t \\
# &=A \Phi(t)\\
# \end{aligned}
# $$
#
# $\Phi(t)$ 是
#
# $$
# x'=Ax
# $$
#
# 的解矩阵 , 又因为, $\Phi(0)=E$ , 因此, $\Phi(t)$  是
#
# $$
# x'=Ax
# $$
#
# 的标准基解矩阵。

# %% [markdown]
# **例$１$** 如果 $A$ 是一个对角矩阵
#
# $$
# A=
# \left[
# \begin{matrix}
# a_1&&&\\
# &a_2&&\\
# &&\ddots&\\
# &&&a_n\\
# \end{matrix}
# \right](其中未写出的元素均为零)
# $$
#
# 试求出 $x'= Ax$ 的基解矩阵.

# %% [markdown]
# **解**方程组可以写成
#
# $$
# x_k'=a_kx_k(k=1,2,\dotsi,n)
# $$
#
# 分别积分
#
# $$
# \left[
# \begin{matrix}
# e^{a_1t}\\
# 0\\
# \vdots\\
# 0\\
# \end{matrix}
# \right]
# \quad
# \left[
# \begin{matrix}
# 0\\
# e^{a_2t}\\
# \vdots\\
# 0\\
# \end{matrix}
# \right]
# \dotsi
# \left[
# \begin{matrix}
# 0\\
# 0\\
# \vdots\\
# e^{a_nt}\\
# \end{matrix}
# \right]
# $$
#
#
# $$
# \left[
# \begin{matrix}
# e^{a_1t}&&&\\
# &e^{a_2t}&&\\
# &&\ddots&\\
# &&&e^{a_nt}\\
# \end{matrix}
# \right]
# $$
#
# $$
# \exp At=E+\left[
# \begin{matrix}
# a_1&&&\\
# &a_2&&\\
# &&\ddots&\\
# &&&a_n\\
# \end{matrix}
# \right]\frac{t}{1!}+
# \left[
# \begin{matrix}
# {a_1}^2&&&\\
# &{a_2}^2&&\\
# &&\ddots&\\
# &&&{a_n}^2\\
# \end{matrix}
# \right]\frac{t^2}{2!}+\dots+\left[
# \begin{matrix}
# {a_1}^k&&&\\
# &{a_2}^k&&\\
# &&\ddots&\\
# &&&{a_n}^k\\
# \end{matrix}
# \right]\frac{t^k}{k!}
# +\dots=\left[
# \begin{matrix}
# e^{a_1t}&&&\\
# &e^{a_2t}&&\\
# &&\ddots&\\
# &&&e^{a_nt}\\
# \end{matrix}
# \right]
# $$
#
#
# 据定理 $9$, 这就是基解矩阵.

# %% [markdown]
# **例$2$**试求
#
# $$
# x'=\left[
# \begin{matrix}
# 2&1\\
# 0&2\\
# \end{matrix}
# \right]x
# $$
#
# 的基解矩阵.

# %% [markdown]
# **解**
# $$
#  A= \left[
# \begin{matrix}
# 2&1\\
# 0&2\\
# \end{matrix}
# \right]=
# \left[
# \begin{matrix}
# 2&0\\
# 0&2\\
# \end{matrix}
# \right]+\left[
# \begin{matrix}
# 0&1\\
# 0&0\\
# \end{matrix}
# \right]
# $$
#
# 以验证后面的两个矩阵是可交换的 , 得到
#
# $$
# \begin{aligned}
# \exp At
# &=\exp \left[
# \begin{matrix}
# 2&0\\
# 0&2\\
# \end{matrix}
# \right]t\cdot exp\left[
# \begin{matrix}
# 0&1\\
# 0&0\\
# \end{matrix}
# \right]t\\
# &=
# \left[
# \begin{matrix}
# e^{2t}&0\\
# 0&e^{2t}\\
# \end{matrix}
# \right]\{E+\left[
# \begin{matrix}
# 0&1\\
# 0&0\\
# \end{matrix}
# \right]t+\left[
# \begin{matrix}
# 0&1\\
# 0&0\\
# \end{matrix}
# \right]^2\frac{t^2}{2!}+\dots\}
# \end{aligned}
# $$
#
# 但是
#
# $$
# \left[
# \begin{matrix}
# 0&1\\
# 0&0\\
# \end{matrix}
# \right]^2=\left[
# \begin{matrix}
# 0&0\\
# 0&0\\
# \end{matrix}
# \right]
# $$
#
# $$
# exp At=\left[
# \begin{matrix}
# e^{2t}&0\\
# 0&e^{2t}\\
# \end{matrix}
# \right]\{E+\left[
# \begin{matrix}
# 0&1\\
# 0&0\\
# \end{matrix}
# \right]t\}
# $$
#
# 因此 , 基解矩阵就是
#
# $$
# exp At=e^{2t}\left[
# \begin{matrix}
# 1&t\\
# 0&1\\
# \end{matrix}
# \right]=
# \left[
# \begin{matrix}
# e^t&te^t\\
# 0&e^t\\
# \end{matrix}
# \right]
# $$

# %% [markdown]
# ### 5.3.2 基解矩阵的计算公式

# %% [markdown]
# $$
# x'=Ax
# $$
#
# 若
#
# $$
# x'=Ax
# $$
#
# 有 $\varphi(t)=e^{\lambda t}c$ , $c\neq0$ 的解 ,其中常数 $\lambda$ 和向量 $c$  是待定的
# .
#
# $$
# \lambda e^{\lambda t}c=A e^\lambda e^{\lambda t}
# $$
#
# 因为 $e^{\lambda t}\neq0$
#
# $$
# (\lambda E-A)c=0
# $$
#
# 反过来, $\lambda$ 和向量 $c$ 满足方程组
#
# $$
# (\lambda E-A)c=0
# $$
#
# 则
#
# $$
# (e^{\lambda t}c)'=A(e^{\lambda t}c)
# $$

# %% [markdown]
# e^{\lambda t}c 是
# $$
# x'=Ax
# $$
#
# 的非零解 $\iff$ $\lambda$ 和 $c$ 满足方程 $(\lambda E-A)c=0$ , $c\neq 0$ ,$p(\lambda)=\mid\lambda E-A\mid=0$ 特征方程,$\lambda$ 是 $A$ 的特征值,$c$ 是 $A$ 的属于 $λ$ 的特征向量.
#
# $e^{\lambda}c$ 是
# $$
# x'=Ax
# $$
#
# 的非零解 $\iff$ $\lambda$ 是 $A$的特征值 , $c$ 是 $A$ 的属于　$\lambda$ 的特征向量.

# %% [markdown]
# **例 $3$**求解
#
# $$
# x'=\left[
# \begin{matrix}
# -1&3\\
# 2&-2\\
# \end{matrix}
# \right]x
# $$

# %% [markdown]
# **解**
# $$
# \begin{aligned}
# \mid\lambda E-A\mid=\left[
# \begin{matrix}
# \lambda+1&-3\\
# -2&\lambda+2\\
# \end{matrix}
# \right]&=(\lambda+1)(\lambda+2)-6\\
# &=\lambda^2+3\lambda-4=0
# \end{aligned}
# $$
#
# $$
# \lambda_1=-4,\lambda_2=1
# $$
#
# $$
# (\lambda_1 E-A)c=0,(\lambda_2 E-A)c=0
# $$
#
# $$
# (-4E-A)c=0
# $$
# $$
# 其中　A=\left[
# \begin{matrix}
# -1&3\\
# 2&-2\\
# \end{matrix}
# \right]
# $$

# %% [markdown]
# $$
# \begin{pmatrix}
# -4&-3\\
# -2&-2\\
# \end{pmatrix}
# \begin{pmatrix}
# u_1\\
# u_2\\
# \end{pmatrix}=\begin{pmatrix}
# 0\\
# 0\\
# \end{pmatrix}
# $$
#
# $$
# \begin{pmatrix}
# u_1\\
# u_2\\
# \end{pmatrix}=\begin{pmatrix}
# 1\\
# -1\\
# \end{pmatrix}
# $$
#
# $$
# x_1=e^{-4t}\begin{pmatrix}
# １\\
# －１\\
# \end{pmatrix}
# $$

# %% [markdown]
# $$
# (1E-A)c=0
# $$
#
# $$
# 其中　A=\left[
# \begin{matrix}
# -1&t3\\
# 2&-2\\
# \end{matrix}
# \right]
# $$
#
# $$
# \begin{pmatrix}
# 2&-3\\
# -2&3\\
# \end{pmatrix}
# \begin{pmatrix}
# u_1\\
# u_2\\
# \end{pmatrix}
# =\begin{pmatrix}
# 0\\
# 0\\
# \end{pmatrix}
# $$
#
# $$
# \begin{pmatrix}
# u_1\\
# u_2\\
# \end{pmatrix}=
# \begin{pmatrix}
# 3\\
# 2\\
# \end{pmatrix}
# $$
#
# $$
# x_2=e^t\begin{pmatrix}
# 3\\
# 2\\
# \end{pmatrix}
# $$

# %% [markdown]
# $$
# \Phi(t)=\begin{pmatrix}
# e^{-4t}&3e^t\\
# -e^{-4t}&2e^t\\
# \end{pmatrix}
# $$
#
# $$
# det\Phi(t)={(x_1,x_2)\mid_t=0}=\begin{vmatrix}
# 1&3\\
# -1&2\\
# \end{vmatrix}=5\neq0
# $$
#
# $$
# \begin{aligned}
# x(t)&=\begin{pmatrix}
# e^{-4t}&3e^t\\
# -e^{-4t}&2e^t\\
# \end{pmatrix}\begin{pmatrix}
# c_1\\
# c_2\\
# \end{pmatrix}\\
# &=c_1e^{-4t}\begin{pmatrix}
# 1\\
# -1\\
# \end{pmatrix}+c_2e^t\begin{pmatrix}
# 3\\
# 2\\
# \end{pmatrix}
# \end{aligned}
# $$

# %% [markdown]
# $1$ 如果 $\lambda=\lambda_0$ 是特征方程的单根, 则称 $\lambda_0$ 是简单特征根.
#
# $2$ 如果 $\lambda=\lambda_0$ 是特征方程的 $k$ 重根 (即 $p(\lambda)$ 具有因子 $(\lambda-\lambda_0)^k$ , 而没有因子 $(\lambda-\lambda_0)^{k+1})$ 则称$\lambda_0$ 是 $k$ 重特征根.

# %% [markdown]
# ### 求解常系数线性齐次方程组实基解矩阵的方法之一

# %% [markdown]
# **定理$10$**如果矩阵 $A$ 具有 $n$ 个线性无关的特征向量 $v_1,v_2,\dots,v_n$ ,它们对应的特征值分别为 $\lambda_1,\lambda_2,\dots,\lambda_n$( 不必各不相同), 那么
#
# $$
# \Phi(t)=[e^{\lambda_1t}v_1,e^{\lambda_2t}v_2,\dots,e^{\lambda_nt}v_n]\quad $-\infty\leq t\leq \infty
# $$
#
# 是常系数线性微分方程组
#
# $$
# x'=Ax
# $$
#
# 的一个基解矩阵.

# %% [markdown]
# **证明**每一个向量函数 $e^{\lambda_ji}v_j(j=1,2,\dots,n)$
# 都是
#
# $$
# x'=Ax
# $$
# 的一个解$v_1,v_2,\dots,v_n$ 是线性无关的,
#
# $$
# det\Phi(0)=det[v_1,v_2,\dots,v_n]\neq0
# $$
#
# 所以
#
# $$
# \Phi(t)=[e^{\lambda_1t}v_1,e^{\lambda_2t}v_2,\dots,e^{\lambda_nt}v_n]\quad -\infty\leq t\leq \infty
# $$
# 基解矩阵.

# %% [markdown]
# **注 1** **推论** 如果矩阵 $A$ 具有 $n$ 个互不相同的特征值 $\lambda_1,\lambda_2,\dots,\lambda_n$ ,它们对应的特征 向量分别为 $v_1,v_2,\dots,v_n$ 那么
#
# $$
# \Phi(t)=[e^{\lambda_1t}v_1,e^{\lambda_2t}v_2,\dots,e^{\lambda_nt}v_n]\quad -\infty\leq t\leq \infty
# $$
#
# 是常系数线性微分方程组
#
#
# $$
# x'=Ax
# $$
#
# 的一个基解矩阵.

# %% [markdown]
# **注 2** 标准基解阵的表示 $\exp At=\Phi(t)\Phi^{-1}(0)$
#
# $\exp At$ $\quad$ $\Phi(t)$ $\quad$ $\exp At=\Phi(t)C$ $\quad$ $C=\Phi^{-1}(0)$
#
# **标准基解阵一定为实矩阵**.

# %% [markdown]
# **注 3**
#
# 若实系数线性方程组
#
# $$
# x'=Ax
# $$
#
# 有复值解　$x(t)=u(t)+iv(t)$ , 则其实部 $u(t)$ 与虚部 $v(t)$ 都是
#
# $$
# x'=Ax
# $$
#
# 的解.

# %% [markdown]
# **例 5** 试求解
#
# $$
# x'=Ax
# $$
#
# 其中
# $$
# A=\left[
# \begin{matrix}
# 3&5\\
# -5&3\\
# \end{matrix}
# \right]
# $$

# %% [markdown]
# **解** $1$ 求 $A$ 的特征值和特征向量
#
# $$
# det(A-\lambda E)=\begin{vmatrix}
# 3-\lambda&5\\
# -5&3-\lambda\\
# \end{vmatrix}=\lambda^2-6\lambda+34=0
# $$
#
# $$
# \lambda_{1,2}=3\pm5i
# $$
#
# $$
# (A-\lambda_1 E)u=\left[
# \begin{matrix}
# -5i&5\\
# -5&-５i\\
# \end{matrix}
# \right]\left[
# \begin{matrix}
# u_1\\
# u_2\\
# \end{matrix}
# \right]=0
# $$

# %% [markdown]
# $$
# \begin{cases}
# -iu_1+u_2=0\\
# -u_1-iu_2=0\\
# \end{cases}
# $$
#
# 对于任意常数 $\alpha \neq 0$ , $u=\alpha\left[
# \begin{matrix}
# 1\\
# i\\
# \end{matrix}
# \right]$
# 是对应于 $\lambda_1=3+5i$ 的特征向量,类似的,可以求出对应于 $\lambda_2=3-5i$ 的特征向量为
# $v=\beta\left[
# \begin{matrix}
# i\\
# 1\\
# \end{matrix}
# \right]$ 其中 $\beta\neq0$

# %% [markdown]
# $2$ 求实基解矩阵
#
# $$
# x_1=e^{(3+5i)t}\begin{pmatrix}
# 1\\
# i\\
# \end{pmatrix}
# \quad
# x_2=e^{(3-5i)t}\begin{pmatrix}
# i\\
# 1\\
# \end{pmatrix}
# $$
#
# $$
# \Phi(t)=\left[
# \begin{matrix}
# e^{(3+5i)t}&ie^{(3-5i)t}\\
# ie^{(3+5i)t}&e^{(3-5i)t}\\
# \end{matrix}
# \right]
# $$
#
# 就是一个基解矩阵.
#
# $$
# \exp At=\Phi(t)\Phi(0)^{-1}=\left[
# \begin{matrix}
# e^{(3+5i)t}&ie^{(3-5i)t}\\
# ie^{(3+5i)t}&e^{(3-5i)t}\\
# \end{matrix}
# \right]\left[\begin{matrix}
# 1&i\\
# i&1\\
# \end{matrix}\right]^{-1}=\left[
# \begin{matrix}
# e^{(3+5i)t}&ie^{(3-5i)t}\\
# ie^{(3+5i)t}&e^{(3-5i)t}\\
# \end{matrix}
# \right]\left[\begin{matrix}
# \frac{1}{2}&-\frac{i}{2}\\
# -\frac{i}{2}&\frac{1}{2}\\
# \end{matrix}\right]=e^{3t}\left[\begin{matrix}
# \cos 5t&\sin 5t\\
# -sin 5t&\cos 5t\\
# \end{matrix}\right]
# $$

# %% [markdown]
# **求实基解矩阵的步骤(利用定理 10)**

# %% [markdown]
# 1 计算特征值 , 特征向量;
#
# 2 求解基解矩阵 , 求标准基解矩阵（实）;
#
# 3* 写出方程的通解.
